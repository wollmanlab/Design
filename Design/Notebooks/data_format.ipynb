# %%
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
import anndata
import os

# %%
data_path = '/home/zach/ExternalData/Allen_WMB_2024Mar06'

# %%
available_cells = np.array(pd.read_csv(f"{data_path}/metadata/WMB-10X/20230830/available_cells.csv",index_col=0).index)
shared_genes = np.array(pd.read_csv(f"{data_path}/metadata/WMB-10X/20230830/shared_genes.csv",index_col=0).index)
cell_metadata = pd.read_csv(f"{data_path}/metadata/WMB-10X/20230830/updated_cell_metadata.csv",index_col=0)
ensemble_mapper = pd.read_csv(f"{data_path}/metadata/WMB-10X/20230830/ensemble_mapper.csv",index_col=0)
ensemble_mapper = dict(zip(ensemble_mapper.index, ensemble_mapper['gene_symbol']))
reverse_ensemble_mapper = {i:j for j, i in ensemble_mapper.items()}
cell_metadata = cell_metadata.loc[available_cells]

cell_type_label = 'subclass'
region_label = 'region_of_interest_acronym'


cell_types = np.array(cell_metadata[cell_type_label].unique())
region_types = np.array(cell_metadata[region_label].unique())
print(cell_types.shape[0],region_types.shape[0])
cell_metadata
# Out:
# /tmp/ipykernel_2592803/1618630264.py:3: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   cell_metadata = pd.read_csv(f"{data_path}/metadata/WMB-10X/20230830/updated_cell_metadata.csv",index_col=0)
# 334 29
#                               cell_barcode barcoded_cell_sample_label  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01  TGCGCAGGTTGCGCAC                    045_C01
# CGATGTATCTTGCCGT-042_B01  CGATGTATCTTGCCGT                    042_B01
# GACTAACGTCCTCTTG-040_B01  GACTAACGTCCTCTTG                    040_B01
# GATCGTACAACTGCTA-040_B01  GATCGTACAACTGCTA                    040_B01
# GTGCAGCTCACAGGCC-040_C01  GTGCAGCTCACAGGCC                    040_C01
# ...                                    ...                        ...
# TTTGTTGTCCGGTTCT-346_C06  TTTGTTGTCCGGTTCT                    346_C06
# TTTGTTGTCGGAACTT-417_B03  TTTGTTGTCGGAACTT                    417_B03
# TTTGTTGTCGGTAAGG-454_B03  TTTGTTGTCGGTAAGG                    454_B03
# TTTGTTGTCTACTGAG-577_B03  TTTGTTGTCTACTGAG                    577_B03
# TTTGTTGTCTATGTGG-415_C01  TTTGTTGTCTATGTGG                    415_C01
#
#                                library_label feature_matrix_label entity  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01  L8TX_180829_01_C10         WMB-10Xv2-TH   cell
# CGATGTATCTTGCCGT-042_B01  L8TX_180829_01_B09         WMB-10Xv2-TH   cell
# GACTAACGTCCTCTTG-040_B01  L8TX_180815_01_D08         WMB-10Xv2-TH   cell
# GATCGTACAACTGCTA-040_B01  L8TX_180815_01_D08         WMB-10Xv2-TH   cell
# GTGCAGCTCACAGGCC-040_C01  L8TX_180815_01_E08         WMB-10Xv2-TH   cell
# ...                                      ...                  ...    ...
# TTTGTTGTCCGGTTCT-346_C06  L8TX_200831_01_H10        WMB-10Xv3-STR   cell
# TTTGTTGTCGGAACTT-417_B03  L8TX_201105_01_E01        WMB-10Xv3-STR   cell
# TTTGTTGTCGGTAAGG-454_B03  L8TX_201203_01_E11        WMB-10Xv3-STR   cell
# TTTGTTGTCTACTGAG-577_B03  L8TX_210325_01_A08        WMB-10Xv3-STR   cell
# TTTGTTGTCTATGTGG-415_C01  L8TX_201105_01_H02        WMB-10Xv3-STR   cell
#
#                           brain_section_label library_method  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01                  NaN          10Xv2
# CGATGTATCTTGCCGT-042_B01                  NaN          10Xv2
# GACTAACGTCCTCTTG-040_B01                  NaN          10Xv2
# GATCGTACAACTGCTA-040_B01                  NaN          10Xv2
# GTGCAGCTCACAGGCC-040_C01                  NaN          10Xv2
# ...                                       ...            ...
# TTTGTTGTCCGGTTCT-346_C06                  NaN          10Xv3
# TTTGTTGTCGGAACTT-417_B03                  NaN          10Xv3
# TTTGTTGTCGGTAAGG-454_B03                  NaN          10Xv3
# TTTGTTGTCTACTGAG-577_B03                  NaN          10Xv3
# TTTGTTGTCTATGTGG-415_C01                  NaN          10Xv3
#
#                          region_of_interest_acronym  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01                         TH
# CGATGTATCTTGCCGT-042_B01                         TH
# GACTAACGTCCTCTTG-040_B01                         TH
# GATCGTACAACTGCTA-040_B01                         TH
# GTGCAGCTCACAGGCC-040_C01                         TH
# ...                                             ...
# TTTGTTGTCCGGTTCT-346_C06                       sAMY
# TTTGTTGTCGGAACTT-417_B03                       STRd
# TTTGTTGTCGGTAAGG-454_B03                        LSX
# TTTGTTGTCTACTGAG-577_B03                        LSX
# TTTGTTGTCTATGTGG-415_C01                       STRd
#
#                                            donor_label  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01  Snap25-IRES2-Cre;Ai14-407905
# CGATGTATCTTGCCGT-042_B01  Snap25-IRES2-Cre;Ai14-407901
# GACTAACGTCCTCTTG-040_B01  Snap25-IRES2-Cre;Ai14-404124
# GATCGTACAACTGCTA-040_B01  Snap25-IRES2-Cre;Ai14-404124
# GTGCAGCTCACAGGCC-040_C01  Snap25-IRES2-Cre;Ai14-404124
# ...                                                ...
# TTTGTTGTCCGGTTCT-346_C06  Snap25-IRES2-Cre;Ai14-540565
# TTTGTTGTCGGAACTT-417_B03  Snap25-IRES2-Cre;Ai14-551630
# TTTGTTGTCGGTAAGG-454_B03  Snap25-IRES2-Cre;Ai14-555358
# TTTGTTGTCTACTGAG-577_B03  Snap25-IRES2-Cre;Ai14-568464
# TTTGTTGTCTATGTGG-415_C01  Snap25-IRES2-Cre;Ai14-550848
#
#                                                 donor_genotype  ...  \
# cell_label                                                      ...
# TGCGCAGGTTGCGCAC-045_C01  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# CGATGTATCTTGCCGT-042_B01  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# GACTAACGTCCTCTTG-040_B01  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# GATCGTACAACTGCTA-040_B01  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# GTGCAGCTCACAGGCC-040_C01  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# ...                                                        ...  ...
# TTTGTTGTCCGGTTCT-346_C06  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# TTTGTTGTCGGAACTT-417_B03  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# TTTGTTGTCGGTAAGG-454_B03  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# TTTGTTGTCTACTGAG-577_B03  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
# TTTGTTGTCTATGTGG-415_C01  Snap25-IRES2-Cre/wt;Ai14(RCL-tdT)/wt  ...
#
#                                                       subclass  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01         097 PVHd-SBPV Six3 Prox1 Gaba
# CGATGTATCTTGCCGT-042_B01  203 LGv-SPFp-SPFm Nkx2-2 Tcf7l2 Gaba
# GACTAACGTCCTCTTG-040_B01                     096 PVHd Gsc Gaba
# GATCGTACAACTGCTA-040_B01                     096 PVHd Gsc Gaba
# GTGCAGCTCACAGGCC-040_C01         098 AHN-SBPV-PVHd Pdrm12 Gaba
# ...                                                        ...
# TTTGTTGTCCGGTTCT-346_C06                      334 Microglia NN
# TTTGTTGTCGGAACTT-417_B03                           333 Endo NN
# TTTGTTGTCGGTAAGG-454_B03                           333 Endo NN
# TTTGTTGTCTACTGAG-577_B03                           333 Endo NN
# TTTGTTGTCTATGTGG-415_C01                           333 Endo NN
#
#                                                         supertype  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01         0442 PVHd-SBPV Six3 Prox1 Gaba_1
# CGATGTATCTTGCCGT-042_B01  0837 LGv-SPFp-SPFm Nkx2-2 Tcf7l2 Gaba_4
# GACTAACGTCCTCTTG-040_B01                     0441 PVHd Gsc Gaba_1
# GATCGTACAACTGCTA-040_B01                     0441 PVHd Gsc Gaba_1
# GTGCAGCTCACAGGCC-040_C01         0452 AHN-SBPV-PVHd Pdrm12 Gaba_7
# ...                                                           ...
# TTTGTTGTCCGGTTCT-346_C06                      1194 Microglia NN_1
# TTTGTTGTCGGAACTT-417_B03                           1193 Endo NN_1
# TTTGTTGTCGGTAAGG-454_B03                           1193 Endo NN_1
# TTTGTTGTCTACTGAG-577_B03                           1193 Endo NN_1
# TTTGTTGTCTATGTGG-415_C01                           1193 Endo NN_1
#
#                                                           cluster  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01         1632 PVHd-SBPV Six3 Prox1 Gaba_1
# CGATGTATCTTGCCGT-042_B01  3657 LGv-SPFp-SPFm Nkx2-2 Tcf7l2 Gaba_4
# GACTAACGTCCTCTTG-040_B01                     1625 PVHd Gsc Gaba_1
# GATCGTACAACTGCTA-040_B01                     1625 PVHd Gsc Gaba_1
# GTGCAGCTCACAGGCC-040_C01         1679 AHN-SBPV-PVHd Pdrm12 Gaba_7
# ...                                                           ...
# TTTGTTGTCCGGTTCT-346_C06                      5312 Microglia NN_1
# TTTGTTGTCGGAACTT-417_B03                           5311 Endo NN_1
# TTTGTTGTCGGTAAGG-454_B03                           5311 Endo NN_1
# TTTGTTGTCTACTGAG-577_B03                           5310 Endo NN_1
# TTTGTTGTCTATGTGG-415_C01                           5310 Endo NN_1
#
#                           neurotransmitter_color  class_color subclass_color  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01                 #FF3358      #FF6600        #2E3D66
# CGATGTATCTTGCCGT-042_B01                 #FF3358      #9EF01A        #FFC199
# GACTAACGTCCTCTTG-040_B01                 #FF3358      #FF6600        #3B1FCC
# GATCGTACAACTGCTA-040_B01                 #FF3358      #FF6600        #3B1FCC
# GTGCAGCTCACAGGCC-040_C01                 #FF3358      #FF6600        #BB7ACC
# ...                                          ...          ...            ...
# TTTGTTGTCCGGTTCT-346_C06                 #666666      #825f45        #CC1F4E
# TTTGTTGTCGGAACTT-417_B03                 #666666      #858881        #994567
# TTTGTTGTCGGTAAGG-454_B03                 #666666      #858881        #994567
# TTTGTTGTCTACTGAG-577_B03                 #666666      #858881        #994567
# TTTGTTGTCTATGTGG-415_C01                 #666666      #858881        #994567
#
#                          supertype_color cluster_color  \
# cell_label
# TGCGCAGGTTGCGCAC-045_C01         #9D7ACC       #FFD600
# CGATGTATCTTGCCGT-042_B01         #460F66       #7AA0CC
# GACTAACGTCCTCTTG-040_B01         #854599       #2E6663
# GATCGTACAACTGCTA-040_B01         #854599       #2E6663
# GTGCAGCTCACAGGCC-040_C01         #994017       #2E9931
# ...                                  ...           ...
# TTTGTTGTCCGGTTCT-346_C06         #62CC3D       #651FCC
# TTTGTTGTCGGAACTT-417_B03         #00992A       #CC3D76
# TTTGTTGTCGGTAAGG-454_B03         #00992A       #CC3D76
# TTTGTTGTCTACTGAG-577_B03         #00992A       #FFB473
# TTTGTTGTCTATGTGG-415_C01         #00992A       #FFB473
#
#                          region_of_interest_order region_of_interest_color
# cell_label
# TGCGCAGGTTGCGCAC-045_C01                       23                  #FF00EF
# CGATGTATCTTGCCGT-042_B01                       23                  #FF00EF
# GACTAACGTCCTCTTG-040_B01                       23                  #FF00EF
# GATCGTACAACTGCTA-040_B01                       23                  #FF00EF
# GTGCAGCTCACAGGCC-040_C01                       23                  #FF00EF
# ...                                           ...                      ...
# TTTGTTGTCCGGTTCT-346_C06                       21                  #300099
# TTTGTTGTCGGAACTT-417_B03                       18                  #4D58FF
# TTTGTTGTCGGTAAGG-454_B03                       20                  #00FFCF
# TTTGTTGTCTACTGAG-577_B03                       20                  #00FFCF
# TTTGTTGTCTATGTGG-415_C01                       18                  #4D58FF
#
# [4041288 rows x 27 columns]

# %%
csv_file = '/home/zach/ExternalData/mm10_probes_Oct28_2022.csv'
df = pd.read_csv(csv_file)
gene_list = shared_genes#genes['gene_symbol'].tolist()
gene_set = set(gene_list)
try:
  filtered_df = df[df['gene'].isin(gene_set)]
except KeyError:
  #handling the case that gene column not called gene
  df.columns = [str(col) for col in df.columns]   #make sure all the columns are string to be consistent with reading with csv files
  filtered_df = df[df.iloc[:, -4].isin(gene_set)] #use the original -4 column

df = filtered_df
vector_converter = {gene:cc for gene,cc in df['gname'].value_counts().items()}
mising_genes = []
for gene in gene_list:
    if gene not in vector_converter.keys():
        mising_genes.append(gene)
        vector_converter[gene] = 0
print(len(mising_genes),len(gene_list),df['gname'].unique().shape[0])
constraints = np.array([vector_converter[gene] for gene in gene_list])
constraints = np.clip(constraints,0,100)
gene_m = constraints>0
print(np.sum(gene_m))
genes = gene_list[gene_m]
genes_ensemble = np.array([reverse_ensemble_mapper[gene] for gene in genes])
constraints = constraints[gene_m]
constraints_df = pd.DataFrame(constraints,index=genes,columns=['constraints'])
# Out:
# 10412 32244 21832
# 21832

# %%
constraints_df
# Out:
#                constraints
# 0610009B22Rik            9
# 0610009E02Rik            9
# 0610009L18Rik           11
# 0610010F05Rik           32
# 0610010K14Rik           12
# ...                    ...
# Zyx                     34
# Zzef1                  100
# Zzz3                    74
# a                       12
# ccdc198                 23
#
# [21832 rows x 1 columns]

# %%
""" Class Balance """
tn = 100000
n = int(tn/cell_types.shape[0])
idxs = []
for ct in cell_types:
    m = cell_metadata[cell_type_label]==ct
    if m.sum() > n:
        idxs.extend(np.random.choice(np.where(m)[0], n, replace = False))
    else:
        idxs.extend(np.random.choice(np.where(m)[0], n, replace = True))
chosen_cells = cell_metadata.index[idxs]
chosen_cell_metadata = cell_metadata.loc[chosen_cells]

# %%
X_train = ''
categorical_converter = {k:i for i,k in enumerate(cell_types)}
region_categorical_converter = {k:i for i,k in enumerate(region_types)}
for feature_matrix_label in chosen_cell_metadata['feature_matrix_label'].unique():
    m = chosen_cell_metadata['feature_matrix_label'] == feature_matrix_label
    temp_chosen_cells = chosen_cells[m]
    if '10Xv2' in feature_matrix_label:
        t = '10Xv2'
    elif '10Xv3' in feature_matrix_label:
        t = '10Xv3'
    adata_path = f"{data_path}/expression_matrices/WMB-{t}/20230630/{feature_matrix_label}-raw.h5ad"
    data = anndata.read_h5ad(adata_path,backed='r')
    temp_adata = data[temp_chosen_cells,:].to_memory()[:,genes_ensemble].copy()
    correction = torch.tensor(100000/np.array(temp_adata.obs['library_size']))
    X = torch.tensor(temp_adata.X.todense())*correction[:,None]
    y = torch.tensor(np.array(temp_adata.obs[cell_type_label].map(categorical_converter).values))
    r = torch.tensor(np.array(temp_adata.obs[region_label].map(region_categorical_converter).values))
    idxs = torch.tensor(np.arange(X.shape[0]))
    X_train_temp, X_test_temp, idxs_train_temp, idxs_test_temp = train_test_split(X,idxs, test_size = 0.2, random_state = 42)
    y_train_temp = y[idxs_train_temp]
    y_test_temp = y[idxs_test_temp]
    r_train_temp = r[idxs_train_temp]
    r_test_temp = r[idxs_test_temp]
    if isinstance(X_train, str):
        X_train = X_train_temp
        y_train = y_train_temp
        r_train = r_train_temp
        X_test = X_test_temp
        y_test = y_test_temp
        r_test = r_test_temp
    else:
        X_train = torch.cat([X_train,X_train_temp],0)
        y_train = torch.cat([y_train,y_train_temp],0)
        X_test = torch.cat([X_test,X_test_temp],0)
        y_test = torch.cat([y_test,y_test_temp],0)
        r_train = torch.cat([r_train,r_train_temp],0)
        r_test = torch.cat([r_test,r_test_temp],0)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape,r_train.shape,r_test.shape
# Out:
# (torch.Size([79885, 21832]),
#  torch.Size([19981, 21832]),
#  torch.Size([79885]),
#  torch.Size([19981]),
#  torch.Size([79885]),
#  torch.Size([19981]))

# %%
output_path = f"{data_path}/Training_data/"
if not os.path.exists(output_path):
    os.mkdir(output_path)
pd.DataFrame(categorical_converter.values(),index=categorical_converter.keys(),columns=['label']).to_csv(f"{output_path}/categorical_converter.csv")
pd.DataFrame(region_categorical_converter.values(),index=region_categorical_converter.keys(),columns=['label']).to_csv(f"{output_path}/region_categorical_converter.csv")
constraints_df.to_csv(f"{output_path}/constraints.csv")
torch.save(X_train,f"{output_path}/X_train.pt")
torch.save(y_train,f"{output_path}/y_train.pt")
torch.save(X_test,f"{output_path}/X_test.pt")
torch.save(y_test,f"{output_path}/y_test.pt")
torch.save(r_test,f"{output_path}/r_test.pt")
torch.save(r_train,f"{output_path}/r_train.pt")
